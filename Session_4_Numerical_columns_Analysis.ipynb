# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read visadataset
# Read bank.csv
file_path=r"C:\Users\USER\Documents\Gen_ai\Data science and AI\Data File\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing wage column**

# %%
pwage=visa_df['prevailing_wage']

# %% [markdown]
# - min
#
# - max
#
# - mean
#
# - meadian
#
# - len

# %%
min(pwage)
# Out:
# 2.1367

# %%
np.min(pwage) # numpy
# Out:
# 2.1367

# %%
pwage.min() # pandas
# Out:
# 2.1367

# %%
np.max(pwage)
# Out:
# 319210.27

# %%
np.mean(pwage)
# Out:
# np.float64(74455.81459209183)

# %%
np.median(pwage)
# Out:
# np.float64(70308.20999999999)

# %%
len(pwage)
# Out:
# 25480

# %%
pwage.count()# pandas
# Out:
# np.int64(25480)

# %% [markdown]
# **percentile-quantile**

# %%
# 25percentile value
np.percentile(pwage,25)
# Out:
# np.float64(34015.479999999996)

# %%
np.quantile(pwage,0.25)
# Out:
# np.float64(34015.479999999996)

# %%
np.percentile(pwage,50)
# Out:
# np.float64(70308.20999999999)

# %%
np.quantile(pwage,0.50)
# Out:
# np.float64(70308.20999999999)

# %%
np.percentile(pwage,75)
# Out:
# np.float64(107735.51250000001)

# %%
np.quantile(pwage,0.75)
# Out:
# np.float64(107735.51250000001)

# %%
count=pwage.count()
Min=np.min(pwage)
p_25=np.percentile(pwage,25)
Mean=np.mean(pwage)
Median=np.median(pwage)
p_50=np.percentile(pwage,50)
p_75=np.percentile(pwage,75)
Max=np.max(pwage)
metrics=[count,Min,p_25,Mean,Median,p_50,p_75,Max]
ID=['count','Min','25%','Maen','Median','50%','75%','Max']
pd.DataFrame(metrics,index=ID,columns=['prevailing_wage'])
# Out:
#         prevailing_wage
# count      25480.000000
# Min            2.136700
# 25%        34015.480000
# Maen       74455.814592
# Median     70308.210000
# 50%        70308.210000
# 75%       107735.512500
# Max       319210.270000

# %%
l=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    Min=np.min(pwage)
    p_25=np.percentile(pwage,25)
    Mean=np.mean(pwage)
    Median=np.median(pwage)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    Max=np.max(pwage)
    metrics=[count,Min,p_25,Mean,Median,p_50,p_75,Max]
    l.append(metrics)
l
# Out:
# [[np.int64(25480),
#   -26,
#   np.float64(1022.0),
#   np.float64(5667.043210361067),
#   np.float64(2109.0),
#   np.float64(2109.0),
#   np.float64(3504.0),
#   602069],
#  [np.int64(25480),
#   1800,
#   np.float64(1976.0),
#   np.float64(1979.409929356358),
#   np.float64(1997.0),
#   np.float64(1997.0),
#   np.float64(2005.0),
#   2016],
#  [np.int64(25480),
#   2.1367,
#   np.float64(34015.479999999996),
#   np.float64(74455.81459209183),
#   np.float64(70308.20999999999),
#   np.float64(70308.20999999999),
#   np.float64(107735.51250000001),
#   319210.27]]

# %%
pd.DataFrame(l,index=num,columns=ID).T
# Out:
#         no_of_employees   yr_of_estab  prevailing_wage
# count       25480.00000  25480.000000     25480.000000
# Min           -26.00000   1800.000000         2.136700
# 25%          1022.00000   1976.000000     34015.480000
# Maen         5667.04321   1979.409929     74455.814592
# Median       2109.00000   1997.000000     70308.210000
# 50%          2109.00000   1997.000000     70308.210000
# 75%          3504.00000   2005.000000    107735.512500
# Max        602069.00000   2016.000000    319210.270000

# %%
l=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    Min=np.min(pwage)
    p_25=np.percentile(pwage,25)
    Mean=np.mean(pwage)
    Median=np.median(pwage)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    Max=np.max(pwage)
    metrics=[count,Min,p_25,Mean,Median,p_50,p_75,Max]
    l.append(metrics)
pd.DataFrame(l,index=num,columns=ID)
# Out:
#                  count        Min       25%          Maen    Median       50%  \
# no_of_employees  25480   -26.0000   1022.00   5667.043210   2109.00   2109.00
# yr_of_estab      25480  1800.0000   1976.00   1979.409929   1997.00   1997.00
# prevailing_wage  25480     2.1367  34015.48  74455.814592  70308.21  70308.21
#
#                          75%        Max
# no_of_employees    3504.0000  602069.00
# yr_of_estab        2005.0000    2016.00
# prevailing_wage  107735.5125  319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**
#
# - 25p =34015.48
#
#          - there is a 25percentage of total data has values less than wages  34015.48
#
# - what is the total data
#
#     - 25480
#
# - 25 percentage of taotal data
#
#       - 25480*25/100=6370
#
#       -there is a 6370 employees has wages les than 34015.48

# %%
# step-1: total data : visa_df[pwage]
# step_2:less than 25p 34015.48
#step_3: create a condition
# step_4: extract the True values visa_df[con]
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
con=pwage<p_25
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
len(visa_df[con])
#len(visa_df[con])==25480*25/100 both are same answers
# Out:
# 6370

# %%
pwage=visa_df['prevailing_wage']
p_50=np.percentile(pwage,50)
con1=pwage<p_50
visa_df[con1]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 6                         N             4985         1994
# 7                         N             3035         1924
# 9                         N             2251         1995
# 12                        N           123876         1963
# ...                     ...              ...          ...
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
# 25474                     N             2594         1979
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 6                    South       53635.3900         Year                  Y
# 7                     West         418.2298         Hour                  Y
# 9                    South       67514.7600         Year                  Y
# 12               Northeast       28663.0500         Year                  Y
# ...                    ...              ...          ...                ...
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
# 25474            Northeast       51104.7800         Year                  Y
#
#       case_status
# 0          Denied
# 6       Certified
# 7          Denied
# 9       Certified
# 12      Certified
# ...           ...
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
# 25474   Certified
#
# [12740 rows x 12 columns]

# %%
len(visa_df[con1])
#len(visa_df[con1])==25480*50/100
# Out:
# 12740

# %%
pwage=visa_df['prevailing_wage']
p_75=np.percentile(pwage,75)
con2=pwage<p_75
visa_df[con2]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 3                         N               98         1897
# 5                         N             2339         2012
# 6                         N             4985         1994
# ...                     ...              ...          ...
# 25473                     N             2421         2007
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 5                    South       78252.1400         Year                  Y
# 6                    South       53635.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25473            Northeast       22845.5600         Year                  Y
# 25474            Northeast       51104.7800         Year                  Y
# 25475                South       77092.5700         Year                  Y
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 3          Denied
# 5       Certified
# 6       Certified
# ...           ...
# 25473   Certified
# 25474   Certified
# 25475   Certified
# 25478   Certified
# 25479   Certified
#
# [19110 rows x 12 columns]

# %%
len(visa_df[con2])
#len(visa_df[con2])==25480*75/100
# Out:
# 19110

# %% [markdown]
# **Empirical rule**

# %%
#u-1*sigma to u+1*sigma =68
# step-1 mean of wage
#step-2 std of wage
# step-3 lb=mean-1*sigma
        lb=s1-1*s2
#step-4  ub=mean+1*sigma

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-1*wage_std 
ub=wage_mean+1*wage_std 
lb,ub
con1=wage_data>lb #u-1*sigma
con2=wage_data<ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])==68*25480/100
# Out:
# False

# %%
68*25480/100
# Out:
# 17326.4

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-2*wage_std 
ub=wage_mean+2*wage_std 
lb,ub
con1=wage_data>lb #u-1*sigma
con2=wage_data<ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])==95*25480/100
# Out:
# False

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-3*wage_std 
ub=wage_mean+3*wage_std 
lb,ub
con1=wage_data>lb #u-1*sigma
con2=wage_data<ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])==99.7*25480/100
# Out:
# False

# %% [markdown]
# **empirical rule valid for Normal distribution**
#
# **The above analysis conclude,data does not follow normality**

# %% [markdown]
# **histogram**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **class8-12-25**

# %%
# for one interval we need two values
# 10 intervals so we need 11 values
# function returns 3 outputs
    # count of each interval
    # interval values
    # number of intervals

# %%
wage_data=visa_df['prevailing_wage']
f,values,n=plt.hist(wage_data)

# %%
values
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
f
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
# there are 6038 applicantes has wages between 2.1367 to 31922.95
2.13670000e+00,3.19229500e+04
# Out:
# (2.1367, 31922.95)

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04 
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 6038

# %%
wage_data=visa_df['prevailing_wage']
lb=3.19229500e+04
ub=6.38437634e+04 
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 5504

# %%
wage_data=visa_df['prevailing_wage']
lb=6.38437634e+04
ub=9.57645767e+04 
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 5681

# %%
wage_data=visa_df['prevailing_wage']
lb=9.57645767e+04 
ub=1.27685390e+05 
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 4551

# %%
wage_data=visa_df['prevailing_wage']
lb=1.27685390e+05 
ub=1.59606203e+05 
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 2334

# %%
wage_data=visa_df['prevailing_wage']
lb=1.59606203e+05
ub=1.91527017e+05
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 624

# %%
wage_data=visa_df['prevailing_wage']
lb=1.91527017e+05
ub=2.23447830e+05
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 373

# %%
wage_data=visa_df['prevailing_wage']
lb=2.23447830e+05
ub=2.55368643e+05
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 240

# %%
wage_data=visa_df['prevailing_wage']
lb=2.55368643e+05
ub=2.87289457e+05
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 114

# %%
wage_data=visa_df['prevailing_wage']
lb=2.87289457e+05
ub=3.19210270e+05
con1=wage_data>=lb #u-1*sigma
con2=wage_data<=ub #u+1*sigma 
con=con1& con2    ##u-1*sigma to u+1*sigma 
len(visa_df[con])
# Out:
# 21

# %% [markdown]
# - we understand the **percentile**
#
# - we explore about **empirical rule**
#
# - the **empirical rule** failed
#
# - that means the data does not follow **normal distribution**
#
# - we also checked with **histogram plot**
#
# - histogram plot also supported our resaerch:data does not follow **normality**
#
# - it has **right skew**, so that some **outlires** present
#
# - we need to visualize those **outlire by using **BOXPLOT**

# %%
       IQR   Q1   median    Q3     Q3+1.5IQR
                       |-----:-----|
       o      |--------|     :     |--------|    o  o
                       |-----:-----|
     flier             <----------->            fliers

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
import numpy as np
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1|con2
len(visa_df[con3])
# Out:
# 427

# %%
import numpy as np
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1|con2
len(visa_df[con3])
outliers_df=visa_df[con3]
outliers_df['prevailing_wage']
outliers_df['prevailing_wage'].values
outliers_list=outliers_df['prevailing_wage'].values.tolist()

# %%
# i want to call the each observation of wage data
# if that obersation will available in this 427
# the that observation will replace by median
# otherwise that observation will be available as it is

wage_median=visa_df['prevailing_wage'].median()
wage_data=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in outliers_list:
        new_wage_data.append(wage_median)
    else:
        new_wage_data.append(i)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(new_wage_data)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(new_wage_data,vert=False)
plt.show()

# %% [markdown]
# **winsorization**
#
# - whatever the outliers less than lb fill with lb
#
# - whatever the outliers greater than ub fill with ub
#
# - in numpy we have method clip

# %%
# step-1 : get the wage data values
# step-2 : calculate lb
# step-3 : calculate ub
# step-4 ; check the parameters and apply in numpy np.clip()
# step-5 : again implement above visuvalization analysis
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
wage_data_clip=np.clip(wage_data,lb,ub)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(new_wage_data)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(new_wage_data,vert=False)
plt.show()
